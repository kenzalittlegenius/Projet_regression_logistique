# %%
#Importation des librairies
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#Importation du data set
data= pd.read_csv("weather_forecast_data.csv")

# %%
#data.head()

# %%
#Encodage de la cible : on encode la variable catégorielle en variable binaire numérique
data["Rain"]= data["Rain"].map({"no rain": 0, "rain": 1})

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#data.head()

# %%
#print(data)

# %%
#print(data.isnull().sum())

# %%
#print(data.duplicated().sum())

# %%
#from scipy import stats

#z = stats.zscore(data["Temperature"])
#outliers = data[(z > 3) | (z < -3)]

# %%
#outliers = data[(z > 3) | (z < -3)]
#print(outliers)

# %%
#sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
#plt.show()
#correlation

# %%
#Sélection des variables 
X = data[["Temperature","Humidity","Cloud_Cover"]]
Y = data["Rain"]

# %%
m = len(X)

#Sépration train/test : on applique la standardisation
indices = np.random.permutation(m)
train_size = int(0.8*m)
train_idx = indices[:train_size]
test_idx = indices[train_size:]
X_train = X.iloc[train_idx]
X_train = X_train.reset_index(drop = True)
X_test = X.iloc[test_idx]
Y_train = Y.iloc[train_idx]
Y_test = Y.iloc[test_idx]

# %%
print(X_train.values.shape)
# Out:
# (2000, 3)

# %%
mean = X_train.mean()
std = X_train.std()
X_train = (X_train - mean)/std
X_test = (X_test - mean)/std

# %%
n = X_train.shape[1]
w = np.zeros((n,1))
b = 0
z = X_train.values @ w + b
print(z)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
#Implémentation de la fonction sigmoïde
def sigmoid(z) : 
    return 1/(1+np.exp(-z))

# %%
a = sigmoid(z)

# %%
#print(X_train)
#print(Y_train.values.reshape(-1,1).shape)
#print(a)

# %%
y = Y_train.values.reshape(-1,1)

# %%
#fonction cout (log-loss)
def J(a,y) :
    epsilon = 1e-15
    a = np.clip(a, epsilon, 1-epsilon)
    return -1/m * np.sum(y*np.log(a) + (1-y)*np.log(1-a))

# %%
#def J(a,Y_train) :
    #return -(1/m)*(Y_train.values.reshape(-1,1) @ np.log(a) + (1-Y_train.values.reshape(-1,1)) @ np.log(1-a))

# %%
#pas d'apprentissage
p=0.01

# %%
print(X_train.values.reshape(-1,1))
# Out:
# [[-1.68516709]
#  [ 1.74963938]
#  [ 0.28617306]
#  ...
#  [-0.22459099]
#  [ 1.71631653]
#  [-0.67349503]]

# %%
print(y.shape)
print(w.shape)
# Out:
# (2000, 1)
# (3, 1)

# %%
for i in range(10000) :
    
    z = X_train.values @ w + b
    a = sigmoid(z)
    dw = (1 / m) * X_train.values.T @ (a - Y_train.values.reshape(-1,1))
    db = (1 / m) * np.sum(a - Y_train.values.reshape(-1,1))
    w = w - p * dw
    b = b - p * db

# %%
print(w)
# Out:
# [[-1.26023742]
#  [ 1.66874793]
#  [ 1.44834762]]

# %%
costs = []

for i in range(10000):
    z = X_train.values @ w + b
    a = 1 / (1 + np.exp(-z))
    
    cost = -(1/m) * np.sum(
        Y_train.values.reshape(-1,1)*np.log(a) + 
        (1 - Y_train.values.reshape(-1,1))*np.log(1-a)
    )
    costs.append(cost)
    
    dw = (1/m) * X_train.values.T @ (a - Y_train.values.reshape(-1,1))
    db = (1/m) * np.sum(a - Y_train.values.reshape(-1,1))
    
    w = w - p * dw
    b = b - p * db

# %%
# Plot
plt.plot(costs)
plt.xlabel("Itérations")
plt.ylabel("Coût J")
plt.title("Convergence de la descente de gradient")
plt.show()

# %%
plt.plot(costs[::10])

# %%
#test

# %%
z_test = X_test.values @ w + b
a_test = sigmoid(z_test)
TN = FP = FN = TP = 0

# %%
y_true = Y_test.values.reshape(-1,1)
y_pred = (a_test >= 0.5).astype(int)

for i in range(len(y_true)):
    if y_true[i] == 1 and y_pred[i] == 1:
        TP += 1
    elif y_true[i] == 0 and y_pred[i] == 0:
        TN += 1
    elif y_true[i] == 0 and y_pred[i] == 1:
        FP += 1
    elif y_true[i] == 1 and y_pred[i] == 0:
        FN += 1

# %%
cm = np.array([[TN, FP],
               [FN, TP]])

print("Matrice de confusion :")
print(cm)
# Out:
# Matrice de confusion :
# [[420  15]
#  [ 30  35]]
